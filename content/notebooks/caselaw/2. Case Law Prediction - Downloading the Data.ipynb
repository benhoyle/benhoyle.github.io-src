# %% [markdown]
# # 2. Case Law Prediction - Downloading the Data
#
# This post looks at the steps needed to build a case law dataset. Given a set of feeds from a case law search, we want to download the case page HTML, and then process the page to generate a set of structured data.
#
# In order to be kind to the EPO we need to throttle our requests and rotate IP addresses and user agent strings.

# %% [markdown]
# Robots.txt from the EPO:
# ```
# ### robots.txt for www.epo.org
# # Wed Jan  5 12:38:07 CET 2011
# User-agent: *
# Disallow: /search.html
# Disallow: /search_de.html
# Disallow: /search_fr.html
# Disallow: /*?update*
# Disallow: /*?hp=*
# Disallow: /law-practice/case-law-appeals/pdf
# Disallow: /applying/online-services/security/reader/
# Disallow: /gemsafe
# Disallow: /learning-events/events/conferences/focus-marocco.html
# Disallow: /learning-events/events/conferences/focus-marocco_de.html
# Disallow: /learning-events/events/conferences/focus-marocco_fr.html
# Disallow: /applying/online-services/online-filing/download/pdf.html
# Disallow: /applying/online-services/online-filing/download/pdf_de.html
# Disallow: /applying/online-services/online-filing/download/pdf_fr.html
# ##
# ```

# %%
# Imports
import time
import random
import os, pickle

from collections import OrderedDict

from lxml.html import fromstring
import requests
from itertools import cycle

# Import Beautiful Soup for HTML parsing
from bs4 import BeautifulSoup

# %% [markdown]
# ## Load Feed Data

# %%
def loaddata(filename):
    """Helper function to load data from a pickle file."""
    with open(filename, "rb") as f:
        print("Loading data")
        data = pickle.load(f)
    return data

feedentries = loaddata("feeds.pik")
# Run in reverse date order 
feedentries.reverse()
# Out:
# Loading data

# %% [markdown]
# ## Setup System for Multiple Requests

# %%
# Define a sleep function
def sleep():
    """Wait for a time period in seconds between 1 and 2 s in 0.2 s increments"""
    # Throttling Requests
       
    time.sleep(random.randint(5, 10)/5)

# %% [markdown]
# #### Setup a Set of Proxies
#
# In use it was found that many of these proxies were pretty flakey, or already blacklisted. The methods below start out with a long list of about 50 servers, and then culls this list based on errors and timeouts.

# %%
# Rotating Proxies

def get_proxies():
    """ Get a list of proxies."""
    url = 'https://free-proxy-list.net/'
    response = requests.get(url)
    parser = fromstring(response.text)
    proxies = set()
    for i in parser.xpath('//tbody/tr'):
        if i.xpath('.//td[7][contains(text(),"yes")]'):
            proxy = ":".join([i.xpath('.//td[1]/text()')[0], i.xpath('.//td[2]/text()')[0]])
            proxies.add(proxy)
    return proxies


#If you are copy pasting proxy ips, put in the list below
#proxies = ['121.129.127.209:80', '124.41.215.238:45169', '185.93.3.123:8080', '194.182.64.67:3128', '106.0.38.174:8080', '163.172.175.210:3128', '13.92.196.150:8080']
proxies = get_proxies()

# %%
proxies
# Out:
# ['147.135.210.114:54566',
#  '151.80.140.233:54566',
#  '80.211.4.187:8080',
#  '92.53.73.138:8118']

# %%
random.choice(list(proxies))
# Out:
# '151.80.140.233:54566'

# %% [markdown]
# #### Define a List of User Agent Strings to Use

# %%
# Rotating User Agent Strings
user_agent_list = [
   #Chrome
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (Windows NT 5.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
    #Firefox
    'Mozilla/4.0 (compatible; MSIE 9.0; Windows NT 6.1)',
    'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0)',
    'Mozilla/5.0 (Windows NT 6.1; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (Windows NT 6.2; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.0; Trident/5.0)',
    'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0)',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)',
    'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/6.0)',
    'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729)'
]

# %% [markdown]
# ### Make Requests

# %%
def savedata(data, filename):
    """Helper function to save data to a pickle file."""
    import os, pickle
    with open(filename, "wb") as f:
        pickle.dump(data, f)
        print("Data saved")

# %%
# This method could likely be improved along the lines
# discussed here - https://www.peterbe.com/plog/best-practice-with-retries-with-requests
def make_request(url, headers, proxies):
    proxy = random.choice(proxies)
    
    try:
        # Timeout of less than 1s leads to lots of connection errors
        r = requests.get(url, headers=headers, proxies={"http": proxy, "https": proxy}, timeout=2)
    except Exception as e:
        print("URL - {0} - raised error {1} with proxy {2}".format(url, e.__class__.__name__, proxy))
        proxies.remove(proxy)
        if proxies:
            print("{} proxies remaining".format(len(proxies)))
            sleep()
            return make_request(url, headers, proxies)
        
    if r.status_code == requests.codes.ok:
        return r.text, proxies
    elif r.status_code in [403, 407, 503]:
        # Remove and recycle proxy
        print("URL - {0} - returned status code {1} with proxy {2}".format(url, r.status_code, proxy))
        proxies.remove(proxy)
        if proxies:
            print("{} proxies remaining".format(len(proxies)))
            sleep()
            return make_request(url, headers, proxies)
        else:
            return None, proxies  
    else:
        print("URL - {0} - returned status code {1} and text:\n{2}".format(url, r.status_code, r.text))
        return None, proxies

# %%
def parse_html(case_page_text):
    """ Parse HTML into structured data."""
    soup = BeautifulSoup(case_page_text, "lxml")
    pagebody = soup.find("div", {"id": "pagebody"})
    # Parse table data
    table_entries = pagebody.find_all("tr")
    case_data = OrderedDict()
    for te in table_entries:
        if te.th and te.td:
            fieldname = te.th.text.strip()
            # Get rid of colon
            if ":" in fieldname:
                fieldname = fieldname.split(":")[0]
            
            data = te.td.text.strip()
            # Split multiline data into list
            if "\n" in data:
                data = [d.strip() for d in data.split("\n")]
            # Dash indicates no data
            if data == "-":
                data = None
        
            # Skip the "Download and more information field"
            if "and more information" not in fieldname:
                case_data[fieldname] = data
                
    # Parse decision details
    decision_text = pagebody.find("div", {"id": "body"}).find_all("p", recursive=False)
    decision_dict = OrderedDict()
    current_title = "No title"
    for p in decision_text:
        if p:
            text = p.text.strip()
            # If bold mark as title
            if p.b:
                current_title = text
                decision_dict[current_title] = list()
            elif len(text) > 1:
                # Else add text under title
                decision_dict[current_title].append(text)
    
    case_data["Decision Text"] = decision_dict
    return case_data

# %% [markdown]
# If a proxy returns a 403 we want to remove it from the list of proxies.

# %%
proxies = list(proxies)

# %%
# we'll process in reverse data order
for i, feed in enumerate(feedentries, start=0):
    print("Saving Feed {0} - {1}.".format(i, feed['title']))
    
    case_page_url = feed['link']
    #Pick a random user agent
    user_agent = random.choice(user_agent_list)
    #Set the headers 
    headers = {'User-Agent': user_agent}
    
    if not proxies:
        print("No working proxies")
        break
    
    html, proxies = make_request(case_page_url, headers, proxies)
    
    if not html:
        print("Feed {0} - {1} - {2} did not work.".format(i, feed['title'], case_page_url))
    else:
        parsed_data = parse_html(html)
        cases.append(
            (
                i,
                feed['title'],
                feed['link'],
                parsed_data
            )
        )
        
    sleep()
    
    if i > 0 and ((i % 10) == 0):
        print("Cases data is length: ", len(cases))
        savedata(cases, "parsed_data.pkl")
# Out:
# Saving Feed 2027 - T 0278/96 () of 10.7.2001.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t960278eu1.html - raised error ConnectionError with proxy 213.6.40.142:80
# 48 proxies remaining
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t960278eu1.html - returned status code 403 with proxy 144.217.233.5:3128
# 47 proxies remaining
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t960278eu1.html - raised error ConnectTimeout with proxy 147.75.113.108:8080
# 46 proxies remaining
# Saving Feed 2028 - T 0121/99 () of 11.9.2001.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t990121eu1.html - raised error ProxyError with proxy 188.254.78.108:8888
# 45 proxies remaining
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t990121eu1.html - returned status code 403 with proxy 5.196.169.98:3128
# 44 proxies remaining
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t990121eu1.html - raised error ReadTimeout with proxy 180.244.245.80:80
# 43 proxies remaining
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t990121eu1.html - raised error ConnectTimeout with proxy 82.130.246.69:45619
# 42 proxies remaining
# Saving Feed 2029 - T 1094/97 () of 5.7.2001.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t971094eu1.html - raised error ReadTimeout with proxy 188.166.68.38:3128
# 41 proxies remaining
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t971094eu1.html - returned status code 500 and text:
# <html>
# <head>
#  <title>500 Internal Privoxy Error</title>
#  <link rel="shortcut icon" href="http://config.privoxy.org/error-favicon.ico" type="image/x-icon"></head>
# <body>
# <h1>500 Internal Privoxy Error</h1>
# <p>Privoxy encountered an error while processing your request:</p>
# <p><b>Could not load template file <code>forwarding-failed</code> or one of its included components.</b></p>
# <p>Please contact your proxy administrator.</p>
# <p>If you are the proxy administrator, please put the required file(s)in the <code><i>(confdir)</i>/templates</code> directory.  The location of the <code><i>(confdir)</i></code> directory is specified in the main Privoxy <code>config</code> file.  (It's typically the Privoxy install directory, or <code>/etc/privoxy/</code>).</p>
# </body>
# </html>
#
# Feed 2029 - T 1094/97 () of 5.7.2001 - http://www.epo.org/law-practice/case-law-appeals/recent/t971094eu1.html did not work.
# Saving Feed 2030 - T 0441/97 () of 10.8.2001.
# Cases data is length:  2030
# Data saved
# Saving Feed 2031 - T 0212/99 () of 12.9.2001.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t990212eu1.html - raised error ConnectTimeout with proxy 122.183.139.101:8080
# 40 proxies remaining
# Saving Feed 2032 - T 0071/96 (Stress relieving member/SUMITOMO) of ....
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t960071eu1.html - raised error ReadTimeout with proxy 121.129.127.209:80
# 39 proxies remaining
# Saving Feed 2033 - T 0049/97 () of 1.8.2001.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t970049eu1.html - returned status code 403 with proxy 138.197.131.109:3128
# 38 proxies remaining
# Saving Feed 2034 - T 0612/95 (Interposed silicon carbide layer/KABUSHIKI ....
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t950612eu1.html - returned status code 407 with proxy 187.35.137.97:3128
# 37 proxies remaining
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t950612eu1.html - raised error ReadTimeout with proxy 201.64.157.242:80
# 36 proxies remaining
# Saving Feed 2035 - T 0380/96 (Photovoltaic device/SOLAREX ....
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t960380eu1.html - raised error ConnectTimeout with proxy 80.211.201.9:8888
# 35 proxies remaining
# Saving Feed 2036 - T 0060/01 () of 1.10.2001.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t010060eu1.html - returned status code 403 with proxy 144.217.204.254:3128
# 34 proxies remaining
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t010060eu1.html - raised error ReadTimeout with proxy 181.113.27.99:80
# 33 proxies remaining
# Saving Feed 2037 - T 0508/01 () of 9.10.2001.
# Saving Feed 2038 - T 0712/96 (Printed circuit board/TOSHIBA) of 8.8.2001.
# Saving Feed 2039 - T 1083/96 () of 10.10.2001.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t961083eu1.html - raised error ReadTimeout with proxy 137.74.168.174:8080
# 32 proxies remaining
# Saving Feed 2040 - T 0513/97 (Silicon nitride layer/MATSUSHITA) of 8.10. ....
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t970513eu1.html - returned status code 500 and text:
# <html>
# <head>
#  <title>500 Internal Privoxy Error</title>
#  <link rel="shortcut icon" href="http://config.privoxy.org/error-favicon.ico" type="image/x-icon"></head>
# <body>
# <h1>500 Internal Privoxy Error</h1>
# <p>Privoxy encountered an error while processing your request:</p>
# <p><b>Could not load template file <code>forwarding-failed</code> or one of its included components.</b></p>
# <p>Please contact your proxy administrator.</p>
# <p>If you are the proxy administrator, please put the required file(s)in the <code><i>(confdir)</i>/templates</code> directory.  The location of the <code><i>(confdir)</i></code> directory is specified in the main Privoxy <code>config</code> file.  (It's typically the Privoxy install directory, or <code>/etc/privoxy/</code>).</p>
# </body>
# </html>
#
# Feed 2040 - T 0513/97 (Silicon nitride layer/MATSUSHITA) of 8.10. ... - http://www.epo.org/law-practice/case-law-appeals/recent/t970513eu1.html did not work.
# Cases data is length:  2039
# Data saved
# Saving Feed 2041 - T 0251/99 () of 9.10.2001.
# Saving Feed 2042 - T 0430/98 () of 6.11.2001.
# Saving Feed 2043 - T 0698/98 () of 12.10.2001.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t980698eu1.html - raised error ReadTimeout with proxy 185.119.56.8:53281
# 31 proxies remaining
# Saving Feed 2044 - T 0366/97 () of 2.10.2001.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t970366eu1.html - raised error ProxyError with proxy 89.22.175.42:8080
# 30 proxies remaining
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t970366eu1.html - raised error ProxyError with proxy 103.92.142.147:53281
# 29 proxies remaining
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t970366eu1.html - returned status code 403 with proxy 198.50.243.147:3128
# 28 proxies remaining
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t970366eu1.html - raised error ConnectionError with proxy 59.106.215.9:3128
# 27 proxies remaining
# Saving Feed 2045 - T 0290/97 () of 5.11.2001.
# Saving Feed 2046 - T 1058/97 () of 5.11.2001.
# Saving Feed 2047 - T 0177/99 () of 7.12.2001.
# Saving Feed 2048 - T 0612/98 (Dicing appatatus/TOKYO SEIMITSU) of 3.12 ....
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t980612eu1.html - returned status code 403 with proxy 128.199.199.41:3128
# 26 proxies remaining
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t980612eu1.html - raised error ConnectTimeout with proxy 159.224.176.205:53281
# 25 proxies remaining
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t980612eu1.html - raised error ConnectTimeout with proxy 122.183.243.68:8080
# 24 proxies remaining
# Saving Feed 2049 - T 0714/98 () of 6.11.2001.
# Saving Feed 2050 - T 0630/99 () of 12.12.2001.
# Cases data is length:  2049
# Data saved
# Saving Feed 2051 - T 0679/98 () of 10.10.2001.
# Saving Feed 2052 - T 0786/98 () of 8.10.2001.
# Saving Feed 2053 - T 0916/97 () of 7.11.2001.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t970916eu1.html - raised error ConnectTimeout with proxy 46.151.253.128:53281
# 23 proxies remaining
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t970916eu1.html - raised error ReadTimeout with proxy 88.200.251.94:8080
# 22 proxies remaining
# Saving Feed 2054 - T 0581/99 (A control device/HITACHI) of 10.11.2000.
# Saving Feed 2055 - T 0510/97 (Stimulating heart inspection apparatus ....
# Saving Feed 2056 - T 0948/97 () of 9.1.2002.
# Saving Feed 2057 - T 1144/98 (Spread spectrum communication/INTELLON ....
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t981144eu1.html - raised error ReadTimeout with proxy 117.6.161.118:53281
# 21 proxies remaining
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t981144eu1.html - raised error ConnectTimeout with proxy 194.126.183.141:53281
# 20 proxies remaining
# Saving Feed 2058 - T 0492/00 (Channel switching system/NEC) of 12.10. ....
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t000492eu1.html - raised error ConnectTimeout with proxy 5.189.146.57:80
# 19 proxies remaining
# Saving Feed 2059 - T 0502/99 () of 5.2.2002.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t990502eu1.html - raised error ReadTimeout with proxy 188.120.232.181:8118
# 18 proxies remaining
# Saving Feed 2060 - T 0807/99 () of 7.2.2002.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t990807eu1.html - raised error ProxyError with proxy 142.44.194.14:3128
# 17 proxies remaining
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t990807eu1.html - raised error ConnectTimeout with proxy 31.28.5.185:63909
# 16 proxies remaining
# Cases data is length:  2059
# Data saved
# Saving Feed 2061 - T 0923/96 () of 7.12.2001.
# Saving Feed 2062 - T 0148/00 () of 6.2.2002.
# Saving Feed 2063 - T 1116/01 () of 6.3.2002.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t011116eu1.html - raised error ReadTimeout with proxy 192.116.142.153:8080
# 15 proxies remaining
# Saving Feed 2064 - T 0734/95 (Etching mask/AT&T) of 6.3.2002.
# Saving Feed 2065 - T 0636/96 () of 12.3.2002.
# Saving Feed 2066 - T 1084/01 () of 6.3.2002.
# Saving Feed 2067 - T 0420/99 (Video signal processing system/D2B ....
# Saving Feed 2068 - T 1090/99 (Spindle drive system/MITSUBISHI) of 5.12. ....
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t991090eu1.html - raised error ReadTimeout with proxy 80.211.13.152:3128
# 14 proxies remaining
# Saving Feed 2069 - T 0784/99 () of 9.4.2002.
# Saving Feed 2070 - T 0195/98 () of 5.2.2002.
# Cases data is length:  2069
# Data saved
# Saving Feed 2071 - T 0160/98 () of 12.12.2001.
# Saving Feed 2072 - T 0220/98 (Liquid phase deposition/TOSHIBA) of 12.3. ....
# Saving Feed 2073 - T 0642/00 (Combined radio receiver and telephone ....
# Saving Feed 2074 - T 0114/00 () of 12.4.2002.
# Saving Feed 2075 - T 0636/99 () of 10.4.2002.
# Saving Feed 2076 - T 0197/99 () of 11.4.2002.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t990197eu1.html - raised error ReadTimeout with proxy 47.206.51.67:8080
# 13 proxies remaining
# Saving Feed 2077 - T 0679/01 () of 2.5.2002.
# Saving Feed 2078 - T 0625/01 () of 10.4.2002.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t010625eu1.html - raised error ReadTimeout with proxy 88.99.149.188:31288
# 12 proxies remaining
# Saving Feed 2079 - T 0380/00 () of 7.5.2002.
# Saving Feed 2080 - T 0763/99 () of 4.6.2002.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t990763eu1.html - raised error ReadTimeout with proxy 163.172.175.210:3128
# 11 proxies remaining
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t990763eu1.html - raised error ReadTimeout with proxy 185.93.3.123:8080
# 10 proxies remaining
# Cases data is length:  2079
# Data saved
# Saving Feed 2081 - T 0906/00 (Radio communication network/INVENTAHL) ....
# Saving Feed 2082 - T 0754/01 (PBX telephone system/AT&T) of 10.5.2002.
# Saving Feed 2083 - T 1081/99 (Film analyzing method/FUJI) of 5.2.2002.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t991081eu1.html - returned status code 403 with proxy 159.65.110.167:3128
# 9 proxies remaining
# Saving Feed 2084 - T 1169/97 () of 3.6.2002.
# Saving Feed 2085 - T 0660/99 () of 2.7.2002.
# Saving Feed 2086 - T 0098/97 () of 9.4.2002.
# Saving Feed 2087 - T 0615/00 () of 11.7.2002.
# Saving Feed 2088 - T 0059/98 () of 10.4.2002.
# Saving Feed 2089 - T 0011/00 (Security coding/AVECIA) of 8.5.2002.
# Saving Feed 2090 - T 0525/01 () of 3.7.2002.
# Cases data is length:  2089
# Data saved
# Saving Feed 2091 - T 0194/98 () of 12.6.2002.
# Saving Feed 2092 - T 0975/99 () of 9.7.2002.
# Saving Feed 2093 - T 1160/98 () of 9.7.2002.
# Saving Feed 2094 - T 0882/00 (PIN Structure/RAMOT) of 4.7.2002.
# Saving Feed 2095 - T 0294/02 () of 6.8.2002.
# Saving Feed 2096 - T 1033/97 () of 8.7.2002.
# Saving Feed 2097 - T 1081/98 () of 7.3.2002.
# Saving Feed 2098 - T 0621/00 (Custom imprinting/EASTMAN KODAK) of ....
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t000621eu1.html - raised error ConnectTimeout with proxy 140.82.5.180:8080
# 8 proxies remaining
# Saving Feed 2099 - T 0735/97 () of 12.7.2002.
# Saving Feed 2100 - T 0871/98 () of 4.7.2002.
# Cases data is length:  2099
# Data saved
# Saving Feed 2101 - T 0537/00 () of 11.7.2002.
# Saving Feed 2102 - T 0315/97 () of 2.10.2002.
# Saving Feed 2103 - T 0652/01 () of 12.9.2002.
# Saving Feed 2104 - T 0293/02 (Transaction reporting/ROCKWELL) of 9.10. ....
# Saving Feed 2105 - T 0371/01 (Image presentation/Xerox) of 11.9.2002.
# Saving Feed 2106 - T 0587/02 (Kernel operations/POWERTV) of 12.9.2002.
# Saving Feed 2107 - T 0723/98 () of 6.8.2002.
# Saving Feed 2108 - T 0573/98 () of 7.10.2002.
# Saving Feed 2109 - T 0488/99 (Bump heights/FUJITSU) of 3.9.2002.
# Saving Feed 2110 - T 1086/97 (Electrochemical process/BP SOLAR ....
# Cases data is length:  2109
# Data saved
# Saving Feed 2111 - T 0017/00 () of 8.10.2002.
# Saving Feed 2112 - T 0154/02 () of 11.10.2002.
# Saving Feed 2113 - T 0236/00 (Information system/ESEL-KRABBE) of 11.6. ....
# Saving Feed 2114 - T 0860/01 () of 11.9.2002.
# Saving Feed 2115 - T 0536/00 () of 8.10.2002.
# Saving Feed 2116 - T 0545/02 () of 7.11.2002.
# Saving Feed 2117 - T 0487/97 () of 7.11.2002.
# Saving Feed 2118 - T 0500/98 () of 11.10.2002.
# Saving Feed 2119 - T 0696/99 (Information medium/TOSHIBA) of 3.7.2002.
# Saving Feed 2120 - T 0670/98 () of 10.10.2002.
# Cases data is length:  2119
# Data saved
# Saving Feed 2121 - T 1150/00 (Driving circuit/YAMAHA) of 1.10.2002.
# Saving Feed 2122 - T 0067/00 () of 6.11.2002.
# Saving Feed 2123 - T 0978/98 () of 10.12.2002.
# Saving Feed 2124 - T 0229/99 (Television receiver/MATSUSHITA) of 5.11. ....
# Saving Feed 2125 - T 1279/01 () of 11.12.2002.
# Saving Feed 2126 - T 0122/01 (Processor clock rate/TEXAS ....
# Saving Feed 2127 - T 0592/02 () of 12.12.2002.
# Saving Feed 2128 - T 0010/00 (Rotating apparatus/MATSUSHITA) of 12.3. ....
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t000010eu1.html - raised error ReadTimeout with proxy 66.82.144.29:8080
# 7 proxies remaining
# Saving Feed 2129 - T 0012/00 () of 7.11.2002.
# Saving Feed 2130 - T 0519/00 () of 2.12.2002.
# Cases data is length:  2129
# Data saved
# Saving Feed 2131 - T 1200/01 (Night letter-box/APPLIED MATERIALS, INC. ....
# Saving Feed 2132 - T 1080/98 () of 6.11.2002.
# Saving Feed 2133 - T 0739/98 () of 3.12.2002.
# Saving Feed 2134 - T 0644/02 () of 9.1.2003.
# Saving Feed 2135 - T 0744/98 () of 12.11.2002.
# Saving Feed 2136 - T 1158/98 (Perfected machine for the counting and ....
# Saving Feed 2137 - T 0258/97 (Multi-address call/CANON) of 8.2.2002.
# Saving Feed 2138 - T 0832/00 () of 8.1.2003.
# Saving Feed 2139 - T 0658/01 () of 5.12.2002.
# Saving Feed 2140 - T 0049/99 (Information modelling/INTERNATIONAL ....
# Cases data is length:  2139
# Data saved
# Saving Feed 2141 - T 0589/99 () of 3.12.2002.
# Saving Feed 2142 - T 0817/01 () of 11.2.2003.
# Saving Feed 2143 - T 0255/00 (Audiovisual equipment/MATSUSHITA) of ....
# Saving Feed 2144 - T 0738/01 () of 6.2.2003.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t010738eu1.html - raised error ConnectionError with proxy 185.82.212.95:8080
# 6 proxies remaining
# Saving Feed 2145 - T 1011/98 () of 12.12.2002.
# Saving Feed 2146 - T 0947/01 () of 5.2.2003.
# Saving Feed 2147 - T 0040/02 (Antenna feed/NORTEL) of 4.12.2002.
# Saving Feed 2148 - T 0785/99 () of 5.2.2003.
# Saving Feed 2149 - T 1099/98 () of 10.12.2002.
# Saving Feed 2150 - T 0449/00 () of 11.3.2003.
# Cases data is length:  2149
# Data saved
# Saving Feed 2151 - T 1073/98 () of 4.12.2002.
# Saving Feed 2152 - T 0710/99 () of 11.2.2003.
# Saving Feed 2153 - T 1104/99 (Mobile ions/HARRIS) of 4.4.2003.
# Saving Feed 2154 - T 0841/99 () of 7.4.2003.
# Saving Feed 2155 - T 0644/00 (Viewing device/DURAND) of 9.4.2003.
# Saving Feed 2156 - T 1180/00 () of 7.4.2003.
# Saving Feed 2157 - T 0188/00 (Via lead/FUJITSU) of 5.5.2003.
# Saving Feed 2158 - T 0114/99 () of 5.5.2003.
# Saving Feed 2159 - T 0208/02 () of 3.4.2003.
# Saving Feed 2160 - T 0116/98 () of 9.4.2003.
# Cases data is length:  2159
# Data saved
# Saving Feed 2161 - T 0213/01 () of 8.5.2003.
# Saving Feed 2162 - T 0498/99 (Insulated gate type bipolar-transistor with ....
# Saving Feed 2163 - T 0353/99 (Method and apparatus for the classification ....
# Saving Feed 2164 - T 0364/01 () of 10.4.2003.
# Saving Feed 2165 - T 0124/01 (VCR scheduling/STARSIGHT TELECAST) ....
# Saving Feed 2166 - T 0904/00 (Interconnection-point memory/TEXAS ....
# Saving Feed 2167 - T 0971/00 () of 7.5.2003.
# Saving Feed 2168 - T 0280/01 () of 1.7.2003.
# Saving Feed 2169 - T 0778/02 () of 1.7.2003.
# Saving Feed 2170 - T 0214/01 (Teletext receiver/EDICO) of 7.3.2003.
# Cases data is length:  2169
# Data saved
# Saving Feed 2171 - T 0128/01 () of 11.6.2003.
# Saving Feed 2172 - T 0937/00 () of 12.6.2003.
# Saving Feed 2173 - T 0825/00 () of 11.7.2003.
# Saving Feed 2174 - T 0659/00 () of 1.7.2003.
# Saving Feed 2175 - T 0050/01 (Image Processing/CANON) of 9.5.2003.
# Saving Feed 2176 - T 0088/01 () of 8.7.2003.
# Saving Feed 2177 - T 0611/99 () of 11.7.2003.
# Saving Feed 2178 - T 0142/00 () of 9.5.2003.
# Saving Feed 2179 - T 1124/01 () of 8.7.2003.
# Saving Feed 2180 - T 1177/97 (Translating natural languages/SYSTRAN) of ....
# Cases data is length:  2179
# Data saved
# Saving Feed 2181 - T 0922/01 () of 9.7.2003.
# Saving Feed 2182 - T 0111/99 () of 10.7.2003.
# Saving Feed 2183 - T 0060/00 (Value transfer system/MONDEX ....
# Saving Feed 2184 - T 0045/01 () of 5.6.2003.
# Saving Feed 2185 - T 0122/99 () of 7.8.2003.
# Saving Feed 2186 - T 0385/01 () of 2.7.2003.
# Saving Feed 2187 - T 0203/01 () of 5.8.2003.
# Saving Feed 2188 - T 0216/01 () of 6.8.2003.
# Saving Feed 2189 - T 1001/98 () of 10.9.2003.
# Saving Feed 2190 - T 0564/01 () of 11.6.2003.
# Cases data is length:  2189
# Data saved
# Saving Feed 2191 - T 0747/02 (Data transmission method ....
# Saving Feed 2192 - T 0055/01 (Satellite broadcast recording/SONY) of 11.2. ....
# Saving Feed 2193 - T 0733/00 () of 9.9.2003.
# Saving Feed 2194 - T 0196/01 () of 4.9.2003.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t010196eu1.html - raised error ConnectTimeout with proxy 163.172.217.103:3128
# 5 proxies remaining
# Saving Feed 2195 - T 0087/01 () of 11.9.2003.
# Saving Feed 2196 - T 0911/98 (Air conditioner/NIPPONDENSO) of 9.4.2003.
# Saving Feed 2197 - T 1050/00 (Hierarchial encoding/SONY) of 7.8.2003.
# Saving Feed 2198 - T 0619/00 () of 11.9.2003.
# Saving Feed 2199 - T 0979/02 () of 8.10.2003.
# Saving Feed 2200 - T 0061/01 () of 10.9.2003.
# Cases data is length:  2199
# Data saved
# Saving Feed 2201 - T 0550/01 () of 9.10.2003.
# Saving Feed 2202 - T 0053/03 (Revocation at request of patent proprieter) ....
# Saving Feed 2203 - T 0289/01 (Image transmitting apparatus/CANON) of ....
# Saving Feed 2204 - T 0351/99 () of 4.11.2003.
# Saving Feed 2205 - T 0214/00 () of 7.10.2003.
# Saving Feed 2206 - T 1030/01 () of 10.7.2003.
# Saving Feed 2207 - T 1103/01 (Ball grid array/STMICROELECTRONICS) of ....
# Saving Feed 2208 - T 0378/01 (Transparent window antenna/PPG ....
# Saving Feed 2209 - T 0430/02 () of 12.11.2003.
# Saving Feed 2210 - T 0642/03 () of 3.12.2003.
# Cases data is length:  2209
# Data saved
# Saving Feed 2211 - T 0792/01 (Inserted Indicia/PRINCETON) of 9.10.2002.
# Saving Feed 2212 - T 0582/00 () of 3.12.2003.
# Saving Feed 2213 - T 0442/03 () of 12.1.2004.
# Saving Feed 2214 - T 0512/01 () of 5.12.2003.
# Saving Feed 2215 - T 0813/03 () of 7.1.2004.
# Saving Feed 2216 - T 0637/01 () of 10.12.2003.
# Saving Feed 2217 - T 0313/01 (Addressing means and method/MOTOROLA ....
# Saving Feed 2218 - T 0752/01 () of 3.2.2004.
# Saving Feed 2219 - T 0250/01 () of 6.2.2004.
# Saving Feed 2220 - T 0365/01 () of 3.2.2004.
# Cases data is length:  2219
# Data saved
# Saving Feed 2221 - T 0413/00 (On-screen display/SONY) of 5.12.2003.
# Saving Feed 2222 - T 0699/01 (Operation of pointing means/SONY) of ....
# Saving Feed 2223 - T 0253/01 () of 10.12.2003.
# Saving Feed 2224 - T 1018/02 (Telecommunications System/BTG) of 9.12. ....
# Saving Feed 2225 - T 0400/00 () of 10.2.2004.
# Saving Feed 2226 - T 1163/01 () of 6.2.2004.
# Saving Feed 2227 - T 0154/01 (Method of making a circuit board ....
# Saving Feed 2228 - T 0524/99 () of 12.2.2004.
# Saving Feed 2229 - T 0889/01 () of 4.2.2004.
# Saving Feed 2230 - T 0641/01 (Catheters for treating prostate disease ....
# Cases data is length:  2229
# Data saved
# Saving Feed 2231 - T 0678/02 () of 5.2.2004.
# Saving Feed 2232 - T 0262/00 () of 4.3.2004.
# Saving Feed 2233 - T 0808/03 () of 12.2.2004.
# Saving Feed 2234 - T 0631/02 () of 2.3.2004.
# Saving Feed 2235 - T 0697/99 (GPS/NOVATEL) of 4.2.2004.
# Saving Feed 2236 - T 0081/03 (Semiconductor memory device/RAMBUS) of ....
# Saving Feed 2237 - T 0089/02 () of 8.3.2004.
# Saving Feed 2238 - T 0153/99 (Spread Spectrum Communication ....
# Saving Feed 2239 - T 0194/99 () of 7.5.2004.
# Saving Feed 2240 - T 0631/00 () of 5.5.2004.
# Cases data is length:  2239
# Data saved
# Saving Feed 2241 - T 0193/01 () of 4.6.2004.
# Saving Feed 2242 - T 1289/01 () of 7.5.2004.
# Saving Feed 2243 - T 0074/02 () of 2.6.2004.
# Saving Feed 2244 - T 0519/99 (Signal processing/CANON) of 1.4.2004.
# Saving Feed 2245 - T 0424/01 () of 6.7.2004.
# Saving Feed 2246 - T 0927/02 () of 12.7.2004.
# Saving Feed 2247 - T 0987/99 () of 12.5.2004.
# Saving Feed 2248 - T 0462/00 () of 11.8.2004.
# Saving Feed 2249 - T 0574/00 (Synchronized operation of machine tool ....
# Saving Feed 2250 - T 0622/00 (Multi-view imaging system/CANON) of 2.7. ....
# Cases data is length:  2249
# Data saved
# Saving Feed 2251 - T 0080/04 (Optical information recording medium ....
# Saving Feed 2252 - T 0164/02 () of 12.10.2004.
# Saving Feed 2253 - T 0239/02 () of 4.10.2004.
# Saving Feed 2254 - T 0604/01 () of 12.8.2004.
# Saving Feed 2255 - T 1092/04 () of 6.10.2004.
# Saving Feed 2256 - T 0878/02 () of 11.2.2004.
# Saving Feed 2257 - T 1110/03 (Evaluation of evidence/GENERAL ....
# Saving Feed 2258 - T 1110/03 (Appréciation des moyens de preuve ....
# Saving Feed 2259 - T 1110/03 () of 4.10.2004.
# Saving Feed 2260 - T 1110/03 (Beweiswürdigung/GENERAL ELECTRIC ....
# Cases data is length:  2259
# Data saved
# Saving Feed 2261 - T 0577/01 () of 5.10.2004.
# Saving Feed 2262 - T 0521/02 () of 8.10.2004.
# Saving Feed 2263 - T 1194/01 () of 7.10.2004.
# Saving Feed 2264 - T 0644/01 (Iodine solution/PIFFERI) of 2.9.2004.
# Saving Feed 2265 - T 1000/01 (Image decoding method/MATSUSHITA) of ....
# Saving Feed 2266 - T 0528/00 () of 8.12.2004.
# Saving Feed 2267 - T 0613/02 () of 3.12.2004.
# Saving Feed 2268 - T 0845/99 (Hostile interference/DIGI-MEDIA VISION) of ....
# Saving Feed 2269 - T 1059/02 () of 4.10.2004.
# Saving Feed 2270 - T 0856/01 () of 9.11.2004.
# Cases data is length:  2269
# Data saved
# Saving Feed 2271 - T 0061/02 (Measuring gamma-rays of radionuclides in ....
# Saving Feed 2272 - T 0721/04 () of 4.1.2004.
# Saving Feed 2273 - T 0761/03 () of 6.12.2004.
# Saving Feed 2274 - T 1120/03 (Modulating device/NEC) of 3.11.2004.
# Saving Feed 2275 - T 0467/02 () of 6.12.2004.
# Saving Feed 2276 - T 1038/01 () of 9.12.2004.
# Saving Feed 2277 - T 0054/02 (TDM communication system/MOTOROLA) of ....
# Saving Feed 2278 - T 0498/02 (Relative address calculations/FUJITSU) of ....
# Saving Feed 2279 - T 1172/01 (Wide-screen display/THOMSON) of 10.12. ....
# Saving Feed 2280 - T 1153/00 (Inserting data/MICROSOFT) of 10.11.2004.
# Cases data is length:  2279
# Data saved
# Saving Feed 2281 - T 0780/02 (Slip free vertical rack design/SAINT-GOBAIN ....
# Saving Feed 2282 - T 1248/01 () of 4.11.2004.
# Saving Feed 2283 - T 0036/95 (Systems for non-volatile storage of data ....
# Saving Feed 2284 - T 0068/82 () of 6.8.1982.
# Saving Feed 2285 - T 0021/81 (Electromagnetically operated switch) of 10.9 ....
# Saving Feed 2286 - T 0021/81 (Contacteur électromagnétique) of 10.9.1982.
# Saving Feed 2287 - T 0021/81 (Elektromagnetischer Schalter) of 10.9.1982.
# Saving Feed 2288 - T 0021/81 (Electromagnetically operated switch) of 10.9 ....
# Saving Feed 2289 - T 0131/82 () of 3.2.1983.
# Saving Feed 2290 - T 0175/82 () of 3.11.1983.
# Cases data is length:  2289
# Data saved
# Saving Feed 2291 - T 0064/83 () of 9.11.1983.
# Saving Feed 2292 - T 0147/82 () of 5.4.1984.
# Saving Feed 2293 - T 0128/83 () of 8.11.1984.
# Saving Feed 2294 - T 0192/84 (Interruption de la distribution du courrier) of ....
# Saving Feed 2295 - T 0192/84 (Unterbrechung der Postzustellung) of 9.11. ....
# Saving Feed 2296 - T 0192/84 (Interruption in delivery of mail) of 9.11.1984.
# Saving Feed 2297 - T 0035/82 () of 9.1.1985.
# Saving Feed 2298 - T 0094/83 () of 1.3.1985.
# Saving Feed 2299 - T 0287/84 (Restitutio) of 11.6.1985.
# Saving Feed 2300 - T 0287/84 (Wiedereinsetzung) of 11.6.1985.
# Cases data is length:  2299
# Data saved
# Saving Feed 2301 - T 0287/84 (Re-establishment) of 11.6.1985.
# Saving Feed 2302 - T 0287/84 (Re-establishment) of 11.6.1985.
# Saving Feed 2303 - T 0166/82 () of 12.6.1985.
# Saving Feed 2304 - T 0096/83 () of 10.7.1985.
# Saving Feed 2305 - T 0080/84 () of 3.10.1985.
# Saving Feed 2306 - T 0040/83 () of 4.11.1985.
# Saving Feed 2307 - T 0114/84 () of 12.11.1985.
# Saving Feed 2308 - T 0146/82 () of 2.12.1985.
# Saving Feed 2309 - T 0054/83 () of 9.12.1985.
# Saving Feed 2310 - T 0011/84 () of 10.12.1985.
# Cases data is length:  2309
# Data saved
# Saving Feed 2311 - T 0167/82 () of 11.12.1985.
# Saving Feed 2312 - T 0043/83 () of 11.12.1985.
# Saving Feed 2313 - T 0130/85 () of 10.4.1986.
# Saving Feed 2314 - T 0063/83 () of 3.6.1986.
# Saving Feed 2315 - T 0003/84 () of 4.8.1986.
# Saving Feed 2316 - T 0019/85 () of 6.8.1986.
# Saving Feed 2317 - T 0020/85 () of 3.10.1986.
# Saving Feed 2318 - T 0257/85 () of 8.12.1986.
# Saving Feed 2319 - T 0164/86 () of 9.12.1986.
# Saving Feed 2320 - T 0088/85 () of 6.3.1987.
# Cases data is length:  2319
# Data saved
# Saving Feed 2321 - T 0005/83 () of 12.2.1987.
# Saving Feed 2322 - T 0092/84 () of 5.3.1987.
# Saving Feed 2323 - T 0039/86 () of 6.4.1987.
# Saving Feed 2324 - T 0156/84 (Adsorption sous pression alternée) of 9.4. ....
# Saving Feed 2325 - T 0156/84 (Druckwechseladsorption) of 9.4.1987.
# Saving Feed 2326 - T 0156/84 (Pressure swing adsorption) of 9.4.1987.
# Saving Feed 2327 - T 0156/84 (Pressure swing adsorption) of 9.4.1987.
# Saving Feed 2328 - T 0155/84 () of 9.4.1987.
# Saving Feed 2329 - T 0082/83 () of 9.2.1987.
# Saving Feed 2330 - T 0155/83 () of 12.5.1987.
# Cases data is length:  2329
# Data saved
# Saving Feed 2331 - T 0043/87 () of 10.4.1987.
# Saving Feed 2332 - T 0346/86 () of 7.9.1987.
# Saving Feed 2333 - T 0132/83 () of 1.10.1987.
# Saving Feed 2334 - T 0324/86 () of 2.11.1987.
# Saving Feed 2335 - T 0244/86 () of 3.11.1987.
# Saving Feed 2336 - T 0092/86 () of 5.11.1987.
# Saving Feed 2337 - T 0240/84 () of 5.11.1987.
# Saving Feed 2338 - T 0066/85 (Connector) of 9.12.1987.
# Saving Feed 2339 - T 0066/85 (Connecteur) of 9.12.1987.
# Saving Feed 2340 - T 0066/85 (Verbinder) of 9.12.1987.
# Cases data is length:  2339
# Data saved
# Saving Feed 2341 - T 0066/85 (Connector) of 9.12.1987.
# Saving Feed 2342 - T 0104/85 () of 9.10.1987.
# Saving Feed 2343 - T 0178/84 (Absence d'unité d'invention) of 7.12.1987.
# Saving Feed 2344 - T 0178/84 (Unreported lack of unity) of 7.12.1987.
# Saving Feed 2345 - T 0178/84 (Nicht beanstandete Uneinheitlichkeit) of ....
# Saving Feed 2346 - T 0178/84 (Unreported lack of unity) of 7.12.1987.
# Saving Feed 2347 - T 0147/85 () of 1.10.1987.
# Saving Feed 2348 - T 0430/87 () of 11.1.1988.
# Saving Feed 2349 - T 0257/84 () of 11.1.1988.
# Saving Feed 2350 - T 0174/85 () of 4.12.1987.
# Cases data is length:  2349
# Data saved
# Saving Feed 2351 - T 0309/85 () of 8.12.1987.
# Saving Feed 2352 - T 0137/86 () of 8.2.1988.
# Saving Feed 2353 - T 0260/85 (Coaxial Connector) of 9.12.1987.
# Saving Feed 2354 - T 0260/85 (Connecteur coaxial) of 9.12.1987.
# Saving Feed 2355 - T 0260/85 (Koaxialverbinder) of 9.12.1987.
# Saving Feed 2356 - T 0260/85 (Coaxial Connector) of 9.12.1987.
# Saving Feed 2357 - T 0020/86 () of 9.12.1987.
# Saving Feed 2358 - T 0068/86 () of 12.11.1987.
# Saving Feed 2359 - T 0270/87 () of 12.1.1988.
# Saving Feed 2360 - T 0048/86 () of 12.1.1988.
# Cases data is length:  2359
# Data saved
# Saving Feed 2361 - T 0239/85 () of 4.11.1987.
# Saving Feed 2362 - T 0164/87 () of 4.2.1988.
# Saving Feed 2363 - T 0246/85 () of 1.12.1987.
# Saving Feed 2364 - T 0319/86 () of 2.2.1988.
# Saving Feed 2365 - T 0158/85 () of 10.2.1988.
# Saving Feed 2366 - T 0024/85 () of 5.2.1988.
# Saving Feed 2367 - T 0407/86 () of 1.3.1988.
# Saving Feed 2368 - T 0022/83 () of 11.12.1987.
# Saving Feed 2369 - T 0263/87 () of 8.3.1988.
# Saving Feed 2370 - T 0413/86 () of 7.3.1988.
# Cases data is length:  2369
# Data saved
# Saving Feed 2371 - T 0119/86 () of 3.3.1988.
# Saving Feed 2372 - T 0264/84 () of 7.4.1988.
# Saving Feed 2373 - T 0260/86 () of 3.5.1988.
# Saving Feed 2374 - T 0169/86 () of 3.5.1988.
# Saving Feed 2375 - T 0375/86 () of 10.6.1988.
# Saving Feed 2376 - T 0409/87 () of 3.5.1988.
# Saving Feed 2377 - T 0105/86 () of 10.6.1988.
# Saving Feed 2378 - T 0280/86 () of 6.5.1988.
# Saving Feed 2379 - T 0070/87 () of 10.6.1988.
# Saving Feed 2380 - T 0369/87 () of 7.7.1988.
# Cases data is length:  2379
# Data saved
# Saving Feed 2381 - T 0310/87 () of 1.7.1988.
# Saving Feed 2382 - T 0216/86 () of 2.8.1988.
# Saving Feed 2383 - T 0078/84 () of 8.8.1988.
# Saving Feed 2384 - T 0174/86 () of 5.7.1988.
# Saving Feed 2385 - T 0432/86 () of 5.7.1988.
# Saving Feed 2386 - T 0112/87 () of 1.9.1988.
# Saving Feed 2387 - T 0428/86 () of 3.10.1988.
# Saving Feed 2388 - T 0040/84 () of 10.10.1988.
# Saving Feed 2389 - T 0424/87 () of 11.10.1988.
# Saving Feed 2390 - T 0115/85 (Invention concernant un programme d' ....
# Cases data is length:  2389
# Data saved
# Saving Feed 2391 - T 0115/85 (Computerbezogene Erfindung) of 5.9.1988.
# Saving Feed 2392 - T 0115/85 (Computer-related invention) of 5.9.1988.
# Saving Feed 2393 - T 0115/85 (Computer-related invention) of 5.9.1988.
# Saving Feed 2394 - T 0221/87 () of 11.11.1988.
# Saving Feed 2395 - T 0047/87 () of 11.11.1988.
# Saving Feed 2396 - T 0022/85 (Résumé et recherche de documents) of 5.10 ....
# Saving Feed 2397 - T 0022/85 (Zusammenfassung und Wiederauffinden ....
# Saving Feed 2398 - T 0022/85 (Document abstracting and retrieving) of 5.10 ....
# Saving Feed 2399 - T 0022/85 (Document abstracting and retrieving) of 5.10 ....
# Saving Feed 2400 - T 0006/83 (Résau de processeurs de données) of 6.10. ....
# Cases data is length:  2399
# Data saved
# Saving Feed 2401 - T 0006/83 (Data processor network) of 6.10.1988.
# Saving Feed 2402 - T 0006/83 (Datenprozessornetz) of 6.10.1988.
# Saving Feed 2403 - T 0006/83 (Data processor network) of 6.10.1988.
# Saving Feed 2404 - T 0178/87 () of 6.10.1988.
# Saving Feed 2405 - T 0307/88 () of 7.12.1988.
# Saving Feed 2406 - T 0272/86 () of 9.1.1989.
# Saving Feed 2407 - T 0009/88 () of 10.1.1989.
# Saving Feed 2408 - T 0357/86 () of 12.8.1988.
# Saving Feed 2409 - T 0286/87 () of 12.1.1989.
# Saving Feed 2410 - T 0086/87 () of 8.12.1988.
# Cases data is length:  2409
# Data saved
# Saving Feed 2411 - T 0087/87 () of 12.12.1988.
# Saving Feed 2412 - T 0428/87 () of 10.1.1989.
# Saving Feed 2413 - T 0016/85 () of 3.3.1989.
# Saving Feed 2414 - T 0438/88 () of 2.3.1989.
# Saving Feed 2415 - T 0066/88 () of 9.3.1989.
# Saving Feed 2416 - T 0205/86 () of 11.4.1989.
# Saving Feed 2417 - T 0170/86 () of 2.3.1989.
# Saving Feed 2418 - T 0425/86 () of 11.5.1989.
# Saving Feed 2419 - T 0617/88 () of 6.6.1989.
# Saving Feed 2420 - T 0037/88 () of 7.6.1989.
# Cases data is length:  2419
# Data saved
# Saving Feed 2421 - T 0291/88 () of 1.6.1989.
# Saving Feed 2422 - T 0050/87 () of 9.5.1989.
# Saving Feed 2423 - T 0323/88 () of 6.6.1989.
# Saving Feed 2424 - T 0032/88 () of 11.7.1989.
# Saving Feed 2425 - T 0061/88 () of 5.6.1989.
# Saving Feed 2426 - T 0073/89 () of 7.8.1989.
# Saving Feed 2427 - T 0103/88 () of 6.7.1989.
# Saving Feed 2428 - T 0066/83 () of 6.6.1989.
# Saving Feed 2429 - T 0221/85 () of 9.8.1989.
# Saving Feed 2430 - T 0511/88 () of 7.9.1989.
# Cases data is length:  2429
# Data saved
# Saving Feed 2431 - T 0042/87 () of 5.10.1989.
# Saving Feed 2432 - T 0558/88 () of 11.10.1989.
# Saving Feed 2433 - T 0162/87 () of 8.6.1989.
# Saving Feed 2434 - T 0350/88 () of 7.11.1989.
# Saving Feed 2435 - T 0335/87 () of 7.11.1989.
# Saving Feed 2436 - T 0308/88 () of 3.10.1989.
# Saving Feed 2437 - T 0050/89 () of 8.11.1989.
# Saving Feed 2438 - T 0533/88 () of 6.11.1989.
# URL - http://www.epo.org/law-practice/case-law-appeals/recent/t880533eu1.html - raised error ConnectTimeout with proxy 89.236.17.108:3128
# 4 proxies remaining
# Saving Feed 2439 - T 0226/88 () of 11.10.1989.
# Saving Feed 2440 - T 0421/87 () of 6.10.1989.
# Cases data is length:  2439
# Data saved
# Saving Feed 2441 - T 0546/88 () of 9.11.1989.
# Saving Feed 2442 - T 0412/86 () of 3.11.1989.
# Saving Feed 2443 - T 0341/88 () of 9.11.1989.
# Saving Feed 2444 - T 0265/88 () of 7.11.1989.
# Saving Feed 2445 - T 0015/89 () of 1.12.1989.
# Saving Feed 2446 - T 0128/88 () of 12.12.1989.
# Saving Feed 2447 - T 0240/87 () of 8.12.1989.
# Saving Feed 2448 - T 0568/89 () of 10.1.1990.
# Saving Feed 2449 - T 0591/88 () of 12.12.1989.
# Saving Feed 2450 - T 0126/89 () of 10.1.1990.
# Cases data is length:  2449
# Data saved
# Saving Feed 2451 - T 0282/85 () of 5.12.1989.
# Saving Feed 2452 - T 0420/89 () of 8.2.1990.
# Saving Feed 2453 - T 0397/88 () of 11.1.1990.
# Saving Feed 2454 - T 0657/89 () of 7.2.1990.
# Saving Feed 2455 - T 0321/88 () of 6.2.1990.
# Saving Feed 2456 - T 0400/87 () of 1.3.1990.
# Saving Feed 2457 - T 0594/88 () of 8.2.1990.
# Saving Feed 2458 - T 0618/88 () of 6.3.1990.
# Saving Feed 2459 - T 0186/86 () of 5.12.1989.
# Saving Feed 2460 - T 0239/84 () of 7.3.1990.
# Cases data is length:  2459
# Data saved
# Saving Feed 2461 - T 0618/89 () of 7.3.1990.
# Saving Feed 2462 - T 0143/88 () of 4.4.1990.
# Saving Feed 2463 - T 0213/89 () of 10.4.1990.
# Saving Feed 2464 - T 0114/89 () of 9.4.1990.
# Saving Feed 2465 - T 0113/87 () of 10.4.1990.
# Saving Feed 2466 - T 0296/89 () of 3.4.1990.
# Saving Feed 2467 - T 0680/89 () of 8.5.1990.
# Saving Feed 2468 - T 0178/89 () of 3.5.1990.
# Saving Feed 2469 - T 0164/89 () of 3.4.1990.
# Saving Feed 2470 - T 0456/89 () of 3.5.1990.
# Cases data is length:  2469
# Data saved
# Saving Feed 2471 - T 0402/88 () of 10.5.1990.
# Saving Feed 2472 - T 0351/88 () of 3.7.1990.
# Saving Feed 2473 - T 0223/88 () of 6.7.1990.
# Saving Feed 2474 - T 0279/87 () of 3.5.1990.
# Saving Feed 2475 - T 0421/89 () of 12.7.1990.
# Saving Feed 2476 - T 0020/89 () of 5.4.1990.
# Saving Feed 2477 - T 0333/88 () of 8.5.1990.
# Saving Feed 2478 - T 0006/90 () of 3.8.1990.
# Saving Feed 2479 - T 0600/89 () of 10.7.1990.
# Saving Feed 2480 - T 0239/89 () of 7.8.1990.
# Cases data is length:  2479
# Data saved
# Saving Feed 2481 - T 0458/89 () of 8.8.1990.
# Saving Feed 2482 - T 0249/90 () of 7.8.1990.
# Saving Feed 2483 - T 0240/89 () of 2.8.1990.
# Saving Feed 2484 - T 0603/89 (Echelle-repère) of 3.7.1990.
# Saving Feed 2485 - T 0603/89 (Anzeiger) of 3.7.1990.
# Saving Feed 2486 - T 0603/89 (Marker) of 3.7.1990.
# Saving Feed 2487 - T 0603/89 (Marker) of 3.7.1990.
# Saving Feed 2488 - T 0206/89 () of 11.7.1990.
# Saving Feed 2489 - T 0471/89 () of 7.8.1990.
# Saving Feed 2490 - T 0382/89 () of 10.9.1990.
# Cases data is length:  2489
# Data saved
# Saving Feed 2491 - T 0751/89 () of 4.9.1990.
# Saving Feed 2492 - T 0165/89 () of 11.9.1990.
# Saving Feed 2493 - T 0434/89 () of 12.9.1990.
# Saving Feed 2494 - T 0348/89 () of 3.7.1990.
# Saving Feed 2495 - T 0216/89 () of 11.10.1990.
# Saving Feed 2496 - T 0757/89 () of 12.10.1990.
# Saving Feed 2497 - T 0487/88 () of 9.10.1990.
# Saving Feed 2498 - T 0128/89 () of 5.10.1990.
# Saving Feed 2499 - T 0262/89 () of 11.9.1990.
# Saving Feed 2500 - T 0672/89 () of 7.11.1990.
# Cases data is length:  2499
# Data saved
# Saving Feed 2501 - T 0290/90 (Réduction de taxe) of 9.10.1990.
# Saving Feed 2502 - T 0290/90 (Gebührenermässigung) of 9.10.1990.
# Saving Feed 2503 - T 0290/90 (Fee reduction) of 9.10.1990.
# Saving Feed 2504 - T 0290/90 (Fee reduction) of 9.10.1990.
# Saving Feed 2505 - T 0165/90 () of 4.10.1990.
# Saving Feed 2506 - T 0687/89 () of 6.11.1990.
# Saving Feed 2507 - T 0507/90 () of 12.11.1990.
# Saving Feed 2508 - T 0468/89 () of 11.10.1990.
# Saving Feed 2509 - T 0473/90 () of 7.11.1990.
# Saving Feed 2510 - T 0784/89 (Disclosure of computer related apparatus) of ....
# Cases data is length:  2509
# Data saved
# Saving Feed 2511 - T 0784/89 (Divulgation - Dispositif relié à un ordinateur) ....
# Saving Feed 2512 - T 0784/89 (Offenbarung mit einem Computer ....
# Saving Feed 2513 - T 0784/89 (Disclosure of computer related apparatus) of ....
# Saving Feed 2514 - T 0638/89 () of 9.11.1990.
# Saving Feed 2515 - T 0671/89 () of 6.11.1990.
# Saving Feed 2516 - T 0314/89 () of 4.12.1990.
# Saving Feed 2517 - T 0251/90 () of 7.11.1990.
# Saving Feed 2518 - T 0121/90 () of 7.1.1991.
# Saving Feed 2519 - T 0164/90 () of 10.12.1990.
# Saving Feed 2520 - T 0107/90 () of 6.12.1990.
# Cases data is length:  2519
# Data saved
# Saving Feed 2521 - T 0194/89 () of 4.12.1990.
# Saving Feed 2522 - T 0412/89 () of 2.1.1991.
# Saving Feed 2523 - T 0591/89 () of 7.2.1991.
# Saving Feed 2524 - T 0512/89 () of 11.12.1990.
# Saving Feed 2525 - T 0693/89 () of 8.1.1991.
# Saving Feed 2526 - T 0548/90 () of 7.2.1991.
# Saving Feed 2527 - T 0398/88 () of 6.12.1990.
# Saving Feed 2528 - T 0339/89 () of 6.12.1990.
# Saving Feed 2529 - T 0084/89 () of 8.2.1991.
# Saving Feed 2530 - T 0490/90 () of 12.3.1991.
# Cases data is length:  2529
# Data saved
# Saving Feed 2531 - T 0449/89 () of 6.2.1991.
# Saving Feed 2532 - T 0549/90 () of 12.3.1991.
# Saving Feed 2533 - T 0607/90 () of 6.3.1991.
# Saving Feed 2534 - T 0748/90 () of 11.2.1991.
# Saving Feed 2535 - T 0418/90 () of 4.2.1991.
# Saving Feed 2536 - T 0782/89 () of 8.4.1991.
# Saving Feed 2537 - T 0155/89 () of 4.7.1990.
# Saving Feed 2538 - T 0253/90 () of 10.6.1991.
# Saving Feed 2539 - T 0486/90 () of 7.5.1991.
# Saving Feed 2540 - T 0117/87 (Office allemand des brevets) of 6.7.1988.
# Cases data is length:  2539
# Data saved
# Saving Feed 2541 - T 0117/87 (Deutsches Patentamt) of 6.7.1988.
# Saving Feed 2542 - T 0117/87 (German Patent Office) of 6.7.1988.
# Saving Feed 2543 - T 0004/90 () of 12.6.1991.
# Saving Feed 2544 - T 0149/87 () of 8.7.1991.
# Saving Feed 2545 - T 0559/89 () of 5.6.1991.
# Saving Feed 2546 - T 0295/90 () of 8.7.1991.
# Saving Feed 2547 - T 0400/90 () of 3.7.1991.
# Saving Feed 2548 - T 0719/90 () of 7.8.1991.
# Saving Feed 2549 - T 0333/90 () of 12.6.1991.
# Saving Feed 2550 - T 0476/90 () of 10.4.1991.
# Cases data is length:  2549
# Data saved
# Saving Feed 2551 - T 0051/90 () of 8.8.1991.
# Saving Feed 2552 - T 0094/91 () of 9.9.1991.
# Saving Feed 2553 - T 0266/91 () of 12.9.1991.
# Saving Feed 2554 - T 0454/89 () of 11.3.1991.
# Saving Feed 2555 - T 0196/90 () of 12.9.1991.
# Saving Feed 2556 - T 0255/91 (Priority) of 12.9.1991.
# Saving Feed 2557 - T 0255/91 (Priorité) of 12.9.1991.
# Saving Feed 2558 - T 0255/91 (Priorität) of 12.9.1991.
# Saving Feed 2559 - T 0255/91 (Priority) of 12.9.1991.
# Saving Feed 2560 - T 0673/90 () of 3.9.1991.
# Cases data is length:  2559
# Data saved
# Saving Feed 2561 - T 0096/88 () of 10.12.1991.
# Saving Feed 2562 - T 0258/90 () of 12.12.1991.
# Saving Feed 2563 - T 0443/87 () of 9.10.1991.
# Saving Feed 2564 - T 0648/90 () of 11.12.1991.
# Saving Feed 2565 - T 0340/91 () of 5.12.1991.
# Saving Feed 2566 - T 0224/91 () of 6.11.1991.
# Saving Feed 2567 - T 0942/90 () of 3.12.1991.
# Saving Feed 2568 - T 0710/90 () of 4.11.1991.
# Saving Feed 2569 - T 0199/87 () of 7.5.1991.
# Saving Feed 2570 - T 0735/89 () of 9.1.1992.
# Cases data is length:  2569
# Data saved
# Saving Feed 2571 - T 0069/91 () of 11.9.1991.
# Saving Feed 2572 - T 0853/90 () of 11.9.1991.
# Saving Feed 2573 - T 0002/91 () of 10.12.1991.
# Saving Feed 2574 - T 0553/91 () of 11.2.1992.
# Saving Feed 2575 - T 0424/90 () of 11.12.1991.
# Saving Feed 2576 - T 0769/90 () of 11.3.1992.
# Saving Feed 2577 - T 0022/91 () of 11.2.1992.
# Saving Feed 2578 - T 0854/91 () of 4.3.1992.
# Saving Feed 2579 - T 0473/91 (Référence) of 9.4.1992.
# Saving Feed 2580 - T 0473/91 (Jurisdiction) of 9.4.1992.
# Cases data is length:  2579
# Data saved
# Saving Feed 2581 - T 0473/91 (Zuständigkeit) of 9.4.1992.
# Saving Feed 2582 - T 0473/91 (Jurisdiction) of 9.4.1992.
# Saving Feed 2583 - T 0616/91 () of 6.4.1992.
# Saving Feed 2584 - T 0325/91 () of 3.4.1992.
# Saving Feed 2585 - T 0226/91 () of 10.3.1992.
# Saving Feed 2586 - T 0042/91 () of 1.4.1992.
# Saving Feed 2587 - T 0201/91 () of 3.2.1992.
# Saving Feed 2588 - T 0478/90 () of 3.2.1992.
# Saving Feed 2589 - T 0225/91 () of 7.5.1992.
# Saving Feed 2590 - T 0093/90 () of 3.6.1992.
# Cases data is length:  2589
# Data saved
# Saving Feed 2591 - T 0025/91 () of 2.6.1992.
# Saving Feed 2592 - T 0909/90 () of 3.6.1992.
# Saving Feed 2593 - T 0382/87 () of 3.7.1992.
# Saving Feed 2594 - T 0025/92 (Serenoa/INDENA) of 3.7.1992.
# Saving Feed 2595 - T 0162/92 () of 3.7.1992.
# Saving Feed 2596 - T 0950/90 () of 2.7.1992.
# Saving Feed 2597 - T 0111/92 () of 3.8.1992.
# Saving Feed 2598 - T 0869/90 (Electromagnetic borehole logging ....
# Saving Feed 2599 - T 0809/91 () of 7.8.1992.
# Saving Feed 2600 - T 0747/90 () of 5.3.1992.
# Cases data is length:  2599
# Data saved
# Saving Feed 2601 - T 0253/90 () of 4.9.1992.
# Saving Feed 2602 - T 0255/92 () of 9.9.1992.
# Saving Feed 2603 - T 0743/91 () of 10.9.1992.
# Saving Feed 2604 - T 0693/90 () of 11.8.1992.
# Saving Feed 2605 - T 0881/90 () of 9.9.1992.
# Saving Feed 2606 - T 0313/91 () of 6.8.1992.
# Saving Feed 2607 - T 0835/91 () of 7.10.1992.
# Saving Feed 2608 - T 0200/91 () of 6.10.1992.
# Saving Feed 2609 - T 0141/91 () of 12.8.1992.
# Saving Feed 2610 - T 0241/92 () of 2.9.1992.
# Cases data is length:  2609
# Data saved
# Saving Feed 2611 - T 0669/92 () of 2.11.1992.
# Saving Feed 2612 - T 0281/92 () of 6.11.1992.
# Saving Feed 2613 - T 0519/92 () of 1.12.1992.
# Saving Feed 2614 - T 0940/91 () of 12.10.1992.
# Saving Feed 2615 - T 0249/91 () of 4.12.1992.
# Saving Feed 2616 - T 0218/92 () of 9.12.1992.
# Saving Feed 2617 - T 0135/91 () of 4.12.1992.
# Saving Feed 2618 - T 0319/91 () of 8.12.1992.
# Saving Feed 2619 - T 0043/92 () of 2.12.1992.
# Saving Feed 2620 - T 0119/91 () of 2.2.1993.
# Cases data is length:  2619
# Data saved
# Saving Feed 2621 - T 0101/91 () of 1.12.1992.
# Saving Feed 2622 - T 0848/92 () of 12.1.1993.
# Saving Feed 2623 - T 0100/91 () of 7.12.1992.
# Saving Feed 2624 - T 0070/92 () of 12.1.1993.
# Saving Feed 2625 - T 0577/92 () of 8.12.1992.
# Saving Feed 2626 - T 0795/91 (Oral proceedings/MITSUBISHI) of 2.11.1992.
# Saving Feed 2627 - T 0179/91 () of 3.2.1993.
# Saving Feed 2628 - T 0989/91 () of 2.3.1993.
# Saving Feed 2629 - T 1073/92 (Withdrawal of appeal/ALZA) of 11.2.1993.
# Saving Feed 2630 - T 0677/91 (Mass selective ejection/FINNIGAN) of 3.11. ....
# Cases data is length:  2629
# Data saved
# Saving Feed 2631 - T 0280/91 () of 1.2.1993.
# Saving Feed 2632 - T 0692/91 () of 2.3.1993.
# Saving Feed 2633 - T 1094/92 () of 11.3.1993.
# Saving Feed 2634 - T 0155/91 () of 3.12.1992.
# Saving Feed 2635 - T 0349/91 () of 10.3.1993.
# Saving Feed 2636 - T 0875/91 () of 10.3.1993.
# Saving Feed 2637 - T 1086/92 () of 5.4.1993.
# Saving Feed 2638 - T 0734/91 () of 7.4.1992.
# Saving Feed 2639 - T 0775/92 () of 7.4.1993.
# Saving Feed 2640 - T 0748/92 () of 7.4.1993.
# Cases data is length:  2639
# Data saved
# Saving Feed 2641 - T 0618/91 () of 7.4.1993.
# Saving Feed 2642 - T 0955/91 () of 4.2.1993.
# Saving Feed 2643 - T 0577/91 () of 3.5.1993.
# Saving Feed 2644 - T 0733/92 () of 4.5.1993.
# Saving Feed 2645 - T 0777/91 () of 4.5.1993.
# Saving Feed 2646 - T 0187/91 (Source lumineuse) of 11.3.1993.
# Saving Feed 2647 - T 0187/91 (Light source) of 11.3.1993.
# Saving Feed 2648 - T 0187/91 (Lichtquelle) of 11.3.1993.
# Saving Feed 2649 - T 0187/91 (Light source) of 11.3.1993.
# Saving Feed 2650 - T 0633/91 () of 4.5.1993.
# Cases data is length:  2649
# Data saved
# Saving Feed 2651 - T 0784/92 () of 12.5.1993.
# Saving Feed 2652 - T 1028/92 () of 3.5.1993.
# Saving Feed 2653 - T 0781/92 () of 7.7.1993.
# Saving Feed 2654 - T 0081/92 () of 5.7.1993.
# Saving Feed 2655 - T 0265/92 () of 10.5.1993.
# Saving Feed 2656 - T 0071/93 () of 1.6.1993.
# Saving Feed 2657 - T 0720/91 () of 8.7.1993.
# Saving Feed 2658 - T 0920/91 () of 12.2.1993.
# Saving Feed 2659 - T 0918/91 (Sufficient disclosure/ADVANCED MICRO ....
# Saving Feed 2660 - T 0522/90 () of 8.9.1993.
# Cases data is length:  2659
# Data saved
# Saving Feed 2661 - T 0708/92 () of 9.7.1993.
# Saving Feed 2662 - T 0548/92 () of 5.8.1993.
# Saving Feed 2663 - T 0317/93 () of 1.9.1993.
# Saving Feed 2664 - T 0134/91 () of 8.7.1993.
# Saving Feed 2665 - T 0602/92 () of 10.8.1993.
# Saving Feed 2666 - T 0707/91 () of 5.8.1993.
# Saving Feed 2667 - T 0227/92 () of 1.7.1993.
# Saving Feed 2668 - T 0447/92 () of 7.7.1993.
# Saving Feed 2669 - T 1079/92 () of 8.9.1993.
# Saving Feed 2670 - T 0804/92 (Energy-saving refrigeration apparatus) of ....
# Cases data is length:  2669
# Data saved
# Saving Feed 2671 - T 0804/92 (Appareil de réfrigération à économie d' ....
# Saving Feed 2672 - T 0804/92 (Energiesparende Gefriereinrichtung) of 8.9. ....
# Saving Feed 2673 - T 0804/92 (Refrigeration apparatus) of 8.9.1993.
# Saving Feed 2674 - T 0323/93 () of 3.11.1993.
# Saving Feed 2675 - T 0235/91 () of 10.8.1993.
# Saving Feed 2676 - T 0388/91 () of 12.10.1993.
# Saving Feed 2677 - T 0145/93 () of 10.11.1993.
# Saving Feed 2678 - T 0594/92 () of 1.10.1993.
# Saving Feed 2679 - T 0914/92 () of 10.11.1993.
# Saving Feed 2680 - T 0794/91 () of 10.11.1993.
# Cases data is length:  2679
# Data saved
# Saving Feed 2681 - T 0804/91 () of 12.2.1993.
# Saving Feed 2682 - T 0742/92 () of 7.12.1993.
# Saving Feed 2683 - T 1089/92 () of 8.12.1993.
# Saving Feed 2684 - T 0080/93 () of 12.1.1994.
# Saving Feed 2685 - T 0312/91 () of 8.12.1993.
# Saving Feed 2686 - T 0348/91 () of 9.12.1993.
# Saving Feed 2687 - T 1047/92 () of 1.2.1994.
# Saving Feed 2688 - T 0074/92 (Integrated circuit/TEXAS) of 9.12.1993.
# Saving Feed 2689 - T 0537/92 () of 9.2.1994.
# Saving Feed 2690 - T 0797/91 () of 10.12.1993.
# Cases data is length:  2689
# Data saved
# Saving Feed 2691 - T 0622/91 () of 1.2.1994.
# Saving Feed 2692 - T 0179/92 () of 1.3.1994.
# Saving Feed 2693 - T 0884/91 () of 8.2.1994.
# Saving Feed 2694 - T 0353/92 (Slot machine/UNIVERSAL) of 2.12.1993.
# Saving Feed 2695 - T 0598/92 () of 7.12.1993.
# Saving Feed 2696 - T 1036/92 () of 8.2.1994.
# Saving Feed 2697 - T 0647/93 (Vice de procédure) of 6.4.1994.
# Saving Feed 2698 - T 0647/93 (Procedural violation) of 6.4.1994.
# Saving Feed 2699 - T 0647/93 (Verfahrensmangel) of 6.4.1994.
# Saving Feed 2700 - T 0647/93 (Procedural violation) of 6.4.1994.
# Cases data is length:  2699
# Data saved
# Saving Feed 2701 - T 0278/92 () of 8.3.1994.
# Saving Feed 2702 - T 0360/93 () of 10.5.1994.
# Saving Feed 2703 - T 0140/93 () of 9.5.1994.
# Saving Feed 2704 - T 0021/94 (Restitutio/SWIFTS OF SCARBOROUGH) of ....
# Saving Feed 2705 - T 0051/94 () of 8.6.1994.
# Saving Feed 2706 - T 0426/92 () of 3.3.1994.
# Saving Feed 2707 - T 0157/94 () of 8.6.1994.
# Saving Feed 2708 - T 0654/92 () of 3.5.1994.
# Saving Feed 2709 - T 0451/92 () of 10.5.1994.
# Saving Feed 2710 - T 0792/93 () of 4.7.1994.
# Cases data is length:  2709
# Data saved
# Saving Feed 2711 - T 0191/93 () of 7.6.1994.
# Saving Feed 2712 - T 0052/92 () of 8.7.1994.
# Saving Feed 2713 - T 0774/91 (Cardiac Pacer/MEDTRONIC) of 3.5.1994.
# Saving Feed 2714 - T 0381/93 (Re-establishment/RCA Thomson) of 12.8. ....
# Saving Feed 2715 - T 0806/92 () of 8.6.1994.
# Saving Feed 2716 - T 0745/92 () of 8.6.1994.
# Saving Feed 2717 - T 0825/92 () of 10.8.1994.
# Saving Feed 2718 - T 0113/93 () of 7.9.1994.
# Saving Feed 2719 - T 0362/93 () of 5.9.1994.
# Saving Feed 2720 - T 0395/94 () of 9.9.1994.
# Cases data is length:  2719
# Data saved
# Saving Feed 2721 - T 1002/92 (Queueing system) of 6.7.1994.
# Saving Feed 2722 - T 1002/92 (Séquence d'attente des clients) of 6.7.1994.
# Saving Feed 2723 - T 1002/92 (Warteschlangensystem) of 6.7.1994.
# Saving Feed 2724 - T 1002/92 (Queueing system) of 6.7.1994.
# Saving Feed 2725 - T 0347/93 () of 11.7.1994.
# Saving Feed 2726 - T 0808/93 () of 7.10.1994.
# Saving Feed 2727 - T 0423/94 () of 6.10.1994.
# Saving Feed 2728 - T 0384/91 (Conflit) of 11.11.1992.
# Saving Feed 2729 - T 0384/91 (Conflict) of 11.11.1992.
# Saving Feed 2730 - T 0384/91 (Kollision) of 11.11.1992.
# Cases data is length:  2729
# Data saved
# Saving Feed 2731 - T 0384/91 (Conflict) of 11.11.1992.
# Saving Feed 2732 - T 1027/93 () of 11.11.1994.
# Saving Feed 2733 - T 0095/92 () of 9.8.1994.
# Saving Feed 2734 - T 0201/93 (Muscle stimulator/BIOMEDICAL ....
# Saving Feed 2735 - T 0184/93 () of 12.10.1994.
# Saving Feed 2736 - T 0241/94 () of 5.12.1994.
# Saving Feed 2737 - T 1017/92 () of 3.11.1994.
# Saving Feed 2738 - T 0154/93 () of 2.12.1994.
# Saving Feed 2739 - T 0976/92 () of 9.11.1994.
# Saving Feed 2740 - T 0705/92 (Postage meter/PITNEY BOWES INC) of 8.11 ....
# Cases data is length:  2739
# Data saved
# Saving Feed 2741 - T 0846/91 () of 3.12.1994.
# Saving Feed 2742 - T 0203/93 (MITSUBISHI/Wafer) of 1.9.1994.
# Saving Feed 2743 - T 0036/91 () of 6.12.1994.
# Saving Feed 2744 - T 0192/93 () of 8.12.1994.
# Saving Feed 2745 - T 0324/93 () of 7.12.1994.

# %% [markdown]
# So now we have the data for 2745 case. A next step is to build a simple Mongo database to store this information.
